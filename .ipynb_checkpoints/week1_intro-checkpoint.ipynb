# %%
print("Hello, Data Science! My name is Lessar")
# Out:
# Hello, Data Science! My name is Lessar

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
